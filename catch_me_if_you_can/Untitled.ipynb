# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
from sklearn.feature_extraction.text import CountVectorizer, TfidfTransformer
from sklearn.model_selection import TimeSeriesSplit, cross_val_score, GridSearchCV
from sklearn.metrics import roc_auc_score
from sklearn.linear_model import LogisticRegression
from scipy.sparse import csr_matrix, hstack
from sklearn.preprocessing import OneHotEncoder
import eli5
import pickle

# %%
def write_to_submission_file(predicted_labels, out_file, target='target', index_label='session_id'):
    predicted_df = pd.DataFrame(predicted_labels,
                                index = np.arange(1, predicted_labels.shape[0] + 1),
                                columns = [target])
    predicted_df.to_csv(out_file, index_label=index_label)

# %%
train_df = pd.read_csv(r'data/train_sessions.csv', index_col='session_id')
test_df = pd.read_csv(r'data/test_sessions.csv', index_col='session_id')

# %%
# Convert the time columns to datetime type from object
times = ['time%s' %i for i in range(1,11)]
train_df[times] = train_df[times].apply(pd.to_datetime)
test_df[times] = test_df[times].apply(pd.to_datetime)

# Sorting the data by time
train_df.sort_values(by='time1', inplace=True)

train_df.head()
# Out:
#             site1               time1  site2               time2  site3  \
# session_id
# 21669          56 2013-01-12 08:05:57   55.0 2013-01-12 08:05:57    NaN
# 54843          56 2013-01-12 08:37:23   55.0 2013-01-12 08:37:23   56.0
# 77292         946 2013-01-12 08:50:13  946.0 2013-01-12 08:50:14  951.0
# 114021        945 2013-01-12 08:50:17  948.0 2013-01-12 08:50:17  949.0
# 146670        947 2013-01-12 08:50:20  950.0 2013-01-12 08:50:20  948.0
#
#                          time3  site4               time4  site5  \
# session_id
# 21669                      NaT    NaN                 NaT    NaN
# 54843      2013-01-12 09:07:07   55.0 2013-01-12 09:07:09    NaN
# 77292      2013-01-12 08:50:15  946.0 2013-01-12 08:50:15  946.0
# 114021     2013-01-12 08:50:18  948.0 2013-01-12 08:50:18  945.0
# 146670     2013-01-12 08:50:20  947.0 2013-01-12 08:50:21  950.0
#
#                          time5  ...                 time6  site7  \
# session_id                      ...
# 21669                      NaT  ...                   NaT    NaN
# 54843                      NaT  ...                   NaT    NaN
# 77292      2013-01-12 08:50:16  ...   2013-01-12 08:50:16  948.0
# 114021     2013-01-12 08:50:18  ...   2013-01-12 08:50:18  947.0
# 146670     2013-01-12 08:50:21  ...   2013-01-12 08:50:21  946.0
#
#                          time7  site8               time8  site9  \
# session_id
# 21669                      NaT    NaN                 NaT    NaN
# 54843                      NaT    NaN                 NaT    NaN
# 77292      2013-01-12 08:50:16  784.0 2013-01-12 08:50:16  949.0
# 114021     2013-01-12 08:50:19  945.0 2013-01-12 08:50:19  946.0
# 146670     2013-01-12 08:50:21  951.0 2013-01-12 08:50:22  946.0
#
#                          time9 site10              time10 target
# session_id
# 21669                      NaT    NaN                 NaT      0
# 54843                      NaT    NaN                 NaT      0
# 77292      2013-01-12 08:50:17  946.0 2013-01-12 08:50:17      0
# 114021     2013-01-12 08:50:19  946.0 2013-01-12 08:50:20      0
# 146670     2013-01-12 08:50:22  947.0 2013-01-12 08:50:22      0
#
# [5 rows x 21 columns]

# %%
sites = ['site%s' %i for i in range(1,11)]
train_df[sites].fillna(0).astype('int').to_csv('data/train_sessions_text.csv', sep=',', index=None, header=None)
test_df[sites].fillna(0).astype('int').to_csv('data/test_sessions_text.csv', sep=',', index=None, header=None)

# %%
# %%time
cv = CountVectorizer(max_features=50000)

with open('data/train_sessions_text.csv') as inp_train_file:
    X_train = cv.fit_transform(inp_train_file)
with open('data/test_sessions_text.csv') as inp_test_file:
    X_test = cv.transform(inp_test_file)
# Out:
# Wall time: 6.86 s

# %%
X_train.shape, X_test.shape
# Out:
# ((253561, 41592), (82797, 41592))

# %%
y_train = train_df['target'].astype('int')

# %%
time_split = TimeSeriesSplit(n_splits=10)

# %%
[(el[0].shape, el[1].shape) for el in time_split.split(X_train)]
# Out:
# [((23051,), (23051,)),
#  ((46102,), (23051,)),
#  ((69153,), (23051,)),
#  ((92204,), (23051,)),
#  ((115255,), (23051,)),
#  ((138306,), (23051,)),
#  ((161357,), (23051,)),
#  ((184408,), (23051,)),
#  ((207459,), (23051,)),
#  ((230510,), (23051,))]

# %%
logit = LogisticRegression(C=1, random_state=17)

# %%
# %%time

cv_scores = cross_val_score(logit, X_train, y_train, cv=time_split, scoring='roc_auc', n_jobs=-1)
# Out:
# Wall time: 50.8 s

# %%
cv_scores, cv_scores.mean()
# Out:
# (array([0.84222136, 0.66762837, 0.87016601, 0.9456678 , 0.83148685,
#         0.87731504, 0.92626132, 0.85854648, 0.92573906, 0.91166498]),
#  0.8656697278614922)

# %%
logit.fit(X_train, y_train)
# Out:
# C:\Users\Shubham\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# LogisticRegression(C=1, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=17, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False)

# %%
eli5.show_weights(logit, feature_names=feature_names)
# Out:
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <p style="margin-bottom: 0.5em; margin-top: 0em">
#             <b>
#
#         y=1
#
# </b>
#
# top features
#         </p>
#
#     <table class="eli5-weights"
#            style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto; margin-bottom: 2em;">
#         <thead>
#         <tr style="border: none;">
#
#                 <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;" title="Feature weights. Note that weights do not account for feature value scales, so if feature values have different scales, features with highest weights might not be the most important.">
#                     Weight<sup>?</sup>
#                 </th>
#
#             <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#
#         </tr>
#         </thead>
#         <tbody>
#
#             <tr style="background-color: hsl(120, 100.00%, 82.42%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +5.929
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         lachroniquefaciledumercredi.wordpress.com
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 87.23%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +3.755
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         juicing-fr.mo7e.com
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 88.69%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +3.158
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         www.jle.com
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 89.11%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +2.992
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         www.circuit-electronique.fr
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 89.35%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +2.896
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         ws.m6.fr
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 89.39%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +2.880
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         paiement.societe.com
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 89.65%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +2.781
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         www.wikidata.org
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 89.84%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +2.709
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         a291862.wc.s1.b.yahoodns.net
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 90.04%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +2.631
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         www.footdelles.com
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 90.17%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +2.582
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         elgateado.free.fr
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 90.24%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +2.559
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         bce.journaldunet.com
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 90.75%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +2.370
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         www.sofiter.fr
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 90.75%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +2.368
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         static3.logic-immo.com
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 90.76%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +2.366
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         www.solumag.fr
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 90.85%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +2.331
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         www.bboxclub.com
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 90.92%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +2.305
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         i1-js-14-3-01-11074-737651758-i.init.cedexis-radar.net
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 90.98%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +2.283
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         2402051.r.msn.com
#     </td>
#
# </tr>
#
#
#             <tr style="background-color: hsl(120, 100.00%, 90.98%); border: none;">
#                 <td colspan="2" style="padding: 0 0.5em 0 0.5em; text-align: center; border: none; white-space: nowrap;">
#                     <i>&hellip; 914 more positive &hellip;</i>
#                 </td>
#             </tr>
#
#
#
#             <tr style="background-color: hsl(0, 100.00%, 90.59%); border: none;">
#                 <td colspan="2" style="padding: 0 0.5em 0 0.5em; text-align: center; border: none; white-space: nowrap;">
#                     <i>&hellip; 40659 more negative &hellip;</i>
#                 </td>
#             </tr>
#
#
#             <tr style="background-color: hsl(0, 100.00%, 90.59%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -2.428
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         cs-pont-de-dore.footeo.com
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(0, 100.00%, 88.78%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -3.122
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         bricolage.linternaute.com
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(0, 100.00%, 80.00%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -7.126
#     </td>
#     <t

# %%
with open(r"data/site_dic.pkl", "rb") as input_file:
    site_dict = pickle.load(input_file)

# %%
sites_dict = pd.DataFrame(list(site_dict.keys()), index=list(site_dict.values()), columns=['site'])

# %%
sites_dict.iloc[570]
# Out:
# site    bricolage.linternaute.com
# Name: 25111, dtype: object

# %%
feature_names = list(pd.Series(cv.get_feature_names()).astype('int').apply(lambda site: sites_dict.iloc[site]).values.flatten())

# %%
feature_names
# Out:
# ['images.mystockphoto.com',
#  'cdnetworks.static69.com',
#  'i1-js-14-3-01-11074-431860008-i.init.cedexis-radar.net',
#  'i1-js-14-3-01-11074-355046712-i.init.cedexis-radar.net',
#  'www.alfa147-france.net',
#  'pegasus.portal.nom.br',
#  'store.akamai.steamstatic.com',
#  'i1-js-14-3-01-11074-928034736-i.init.cedexis-radar.net',
#  'i1-js-14-3-01-11074-953586925-i.init.cedexis-radar.net',
#  'forum.hackbbs.org',
#  's01.static-shell.com',
#  'le54.blogspot.fr',
#  'mono-project.com',
#  'images-cache.frandroid.com',
#  'i1-js-14-3-01-12160-55914827-i.init.cedexis-radar.net',
#  'i1-js-14-3-01-10322-82158527-i.init.cedexis-radar.net',
#  'oeconomia.net',
#  'secure.logmein.com',
#  'img257.imageshack.us',
#  'www.vigicrues.ecologie.gouv.fr',
#  'www.estudines.com',
#  'aepdaks3.aetndigital.com',
#  'colvibsvt.space-blogs.net',
#  'i1-js-14-3-01-12160-712066075-i.init.cedexis-radar.net',
#  'www.sqlservercentral.com',
#  'video.foxnews.com',
#  'trustlogo.comodo.com',
#  'i1-js-14-3-01-11074-842307118-i.init.cedexis-radar.net',
#  'tankafaire.wordpress.com',
#  'today.duke.edu',
#  'nl-wimg7.ask.fm',
#  'u-ckk52wo2q1.gl.bkln.wc.s1.b.yahoodns.net',
#  'i1-js-14-3-01-12160-792101658-i.init.cedexis-radar.net',
#  'blog.voigt-travel.nl',
#  'www.playdune.com',
#  'lightpics.fr',
#  'images.elektroda.net',
#  'pokemonaprilfools.wikia.com',
#  'static.yalwa.fr',
#  'i1-js-14-3-01-10005-86064453-i.init.cedexis-radar.net',
#  'datasearch2.uts.edu.au',
#  'i1-js-14-3-01-11074-893689283-i.init.cedexis-radar.net',
#  'i83.servimg.com',
#  'www.berkeley.edu',
#  'logiciels.logitheque.com',
#  'www.calpoly.edu',
#  'strasbourg.lafibre.info',
#  'snl.bjmu.edu.cn',
#  'home.scarlet.be',
#  'mylovelycommunity.files.wordpress.com',
#  'assets.rbmaradio.com',
#  'i1-js-14-3-01-10077-963656632-i.init.cedexis-radar.net',
#  'lib.rus.ec',
#  'n.damart.fr',
#  'konrad.com',
#  'gcm.chango.com',
#  'nobodyputsbabyinahorner.files.wordpress.com',
#  'x3.chatforyoursite.com',
#  'vbjester.free.fr',
#  'tile.openstreetmap.org',
#  'www.cadriz.com',
#  'g.lalawan67.com',
#  'www.meteo-chamrousse.com',
#  'i40.servimg.com',
#  'i0.itc.cn',
#  'news.doccheck.com',
#  'ssw.live.com',
#  'uweb.cas.usf.edu',
#  'res.uqee.com',
#  'www.ekstremalne.pl',
#  'med.miami.edu',
#  'www.lesechosdelafranchise.com',
#  'i40.tinypic.com',
#  'simermoz.free.fr',
#  'jonathanlewis.wordpress.com',
#  'www.aisc.org',
#  'r3---sn-cg07lue6.googlevideo.com',
#  'studyka.us2.list-manage.com',
#  'rbth.co.uk',
#  'streamaccess.unas.tv',
#  'www.scribegriff.com',
#  '0w2myakzob.s.ad6media.fr',
#  'www.cbanque.com',
#  'www.psimg.com',
#  'www.overtocht.nl',
#  'www.glyndwr.ac.uk',
#  'i1-js-14-3-01-12160-204140527-i.init.cedexis-radar.net',
#  'i1-js-14-3-01-10077-425827177-i.init.cedexis-radar.net',
#  'd3d94.pf.aclst.com',
#  'www.gcc.fr',
#  'w096299.blob1.ge.tt',
#  'www.craaq.qc.ca',
#  'd3005maefy0evo.cloudfront.net',
#  'drh2.img.digitalriver.com',
#  'cs6045.vk.com',
#  'i1-js-14-3-01-11074-870607222-i.init.cedexis-radar.net',
#  'mindstorms.lego.com',
#  'images.tmcnet.com',
#  'danse-emergence.typepad.fr',
#  'www.caminteresse.fr',
#  'ndll.eklablog.com',
#  'www.chinadrtv.com',
#  'static.francetv.fr',
#  'vocalbit.com',
#  'www.moteur63.com',
#  'forrst.com',
#  'pl.wikipedia.org',
#  'i1-js-14-3-01-10036-377250552-i.init.cedexis-radar.net',
#  'www.infoclimat.fr',
#  'latechnogirl.files.wordpress.com',
#  'www.mobileaks.nl',
#  'ocsp.quovadisglobal.com',
#  'recherche.ign.fr',
#  'media.meltyxtrem.fr',
#  'images.suite101.com',
#  'cache2.citizenside.com',
#  'societies.yourunion.net',
#  '9cdf.f.aclst.com',
#  'bluerobot.com',
#  'dab1nmslvvntp.cloudfront.net',
#  'layout.eurosportplayer.fr',
#  'vieoceane.free.fr',
#  'totalgta.net',
#  'pf.kizoa.com',
#  '495-qyy-925.mktoresp.com',
#  'www.montessori-france.asso.fr',
#  'www.canstockphoto.fr',
#  'doc.openturns.org',
#  'i1-js-14-3-01-11074-495680598-i.init.cedexis-radar.net',
#  'pic2.pbsrc.com',
#  'plus.google.com',
#  'i1-js-14-3-01-10165-568972300-i.init.cedexis-radar.net',
#  'bioinf.spbau.ru',
#  'img120.exs.cx',
#  'campagne.placeojeunes.net',
#  'oxford-www.baynote.net',
#  'uinfo.mail.163.com',
#  'bac-es.digischool.fr',
#  'www.ampl.com',
#  'www.thestupidnetwork.fr',
#  'tr.nl.infonews-club.com',
#  'account.elderscrollsonline.com',
#  'www.urbangirl.fr',
#  'www.habitat.fr',
#  'ceur-ws.org',
#  'i1-js-14-3-01-10035-782338796-i.init.cedexis-radar.net',
#  'www.thetimenow.com',
#  'dba-oracle.com',
#  'laurent16.hautetfort.com',
#  'i1-js-14-3-01-10608-296223766-i.init.cedexis-radar.net',
#  'netstorage.metrolyrics.com',
#  'www.kelkoo.fr',
#  'users.rcn.com',
#  'i1-js-14-3-01-10077-435795994-i.init.cedexis-radar.net',
#  'rheuh.free.fr',
#  'www.terroirsdechefs.com',
#  'www.meteociel.fr',
#  'www.banqueducanada.ca',
#  'wii-loc.mediagen.fr',
#  'www.fatplay.net',
#  'securel.longtailvideo.com',
#  'static.shinken.io',
#  'linux.developpez.com',
#  'i1-js-14-3-01-10074-89112377-i.init.cedexis-radar.net',
#  'prod.cloud.rockstargames.com',
#  'sig.planetside-universe.com',
#  'img2.99.com.cn',
#  'www.aide-oracle.net',
#  'environnement.lefigaro.fr',
#  'lc5oqzvmp6.s.ad6media.fr',
#  'bsz7e41rlb.b.ad6media.fr',
#  'config.mail.163.com',
#  'leplus.nouvelobs.com',
#  'fr.glee.wikia.com',
#  'veilletourisme.s3.amazonaws.com',
#  'px.pub-fit.com',
#  'i1-js-14-3-01-12160-138285583-i.init.cedexis-radar.net',
#  'www.kpmg.com',
#  'a1794.phobos.apple.com',
#  'www.kingsgalleries.com',
#  'www.scom.ulaval.ca',
#  't.gobert.free.fr',
#  'www.gambling-affiliation.com',
#  'www-lium.univ-lemans.fr',
#  'www.creativecommons.org',
#  'www.typo3-solr.com',
#  'www.pconline.com.cn',
#  'piwik.dezup.com',
#  'demo.joomlashine.com',
#  'www.dankulp.com',
#  'ufrsciences.unicaen.fr',
#  'coopredirect.gaopeng.com',
#  '94.docs.google.com',
#  'fr.wikihow.com',
#  'i1-js-14-3-01-10169-360226901-i.init.cedexis-radar.net',
#  'www.handballyzeure.fr',
#  'whatheisteachingme.files.wordpress.com',
#  'i1-js-14-3-01-11544-604923011-i.init.cedexis-radar.net',
#  'i321.photobucket.com',
#  '467-dlq-643.mktoresp.com',
#  'i1-js-14-3-01-11074-760152498-i.init.cedexis-radar.net',
#  'puzzle.blogs.midilibre.com',
#  'pcounter.el-mundo.net',
#  'www.acam-france.org',
#  'maxdesign.developpez.com',
#  'w-3.netcourrier.com',
#  'i1-js-14-3-01-12160-325501927-i.init.cedexis-radar.net',
#  'www.imesh.com',
#  'www.artdeseduire.com',
#  'www.ekaterinawalter.com',
#  's.zol-img.com.cn',
#  'i1-js-14-3-01-11074-119249028-i.init.cedexis-radar.net',
#  'mediamass.net',
#  'i1-js-14-3-01-10077-336329439-i.init.cedexis-radar.net',
#  'popopkiller.free.fr',
#  'www.egaliteetreconciliation.fr',
#  'cdns.complex.com',
#  'assets3.ecologie-shop.com',
#  'business.dell.com',
#  'i1-js-14-3-01-10013-667150512-i.init.cedexis-radar.net',
#  'www.mail.lycos.com',
#  'idealo.fr',
#  'sonatrach.forum-box.com',
#  'i1-js-14-3-01-12160-386829218-i.init.cedexis-radar.net',
#  'i1-js-14-3-01-11641-1417274-i.init.cedexis-radar.net',
#  'www.dicoblog.com',
#  'asset1.serieweb.com',
#  'www.ops-ecat.schneider-electric.com',
#  'lidl.cataloguepromo.fr',
#  'ecobertura.johoop.de',
#  'www.redditweekly.com',
#  'cpm.wargaming.net',
#  'www.netzwerkrecherche.de',
#  'img10.societe.com',
#  'i181.photobucket.com',
#  'i1-js-14-3-01-10036-561949124-i.init.cedexis-radar.net',
#  'anglais.lemonde.fr',
#  'la-perle.over-blog.fr',
#  'www.uslanmam.com',
#  'french.korea.net',
#  'i1-js-14-3-01-11074-760995407-i.init.cedexis-radar.net',
#  'basketsession.fr',
#  'dm6ndb2k9edja.cloudfront.net',
#  'securitemobile.sfr.fr',
#  'communities.sas.com',
#  'i1-js-14-3-01-10013-489174752-i.init.cedexis-radar.net',
#  'www.tunisie-secret.com',
#  'cbssports.com',
#  'medext.the-oz.com',
#  'www.yetisports.fr',
#  'assets.acs.org',
#  'audfredriksen.blogspot.fr',
#  'icon.feedcat.net',
#  'gbrowse.informatics.jax.org',
#  'fit.sh',
#  'www1.umn.edu',
#  'i1-js-14-3-01-11074-999043179-i.init.cedexis-radar.net',
#  'yui.github.io',
#  'images.forum-auto.com',
#  'levi.imageg.net',
#  'www.maxitoys.fr',
#  'btnlavoixdunord.zegive.com',
#  'bns.17173.com',
#  'www.exportprive.fr',
#  'i1-js-14-3-01-10013-605721837-i.init.cedexis-radar.net',
#  'www.askdev.ru',
#  'a.livefreefunwith.me',
#  'eulerian.grosbill.com',
#  'i1-js-14-3-01-10013-500407792-i.init.cedexis-radar.net',
#  'cinemadocumentaire.wordpress.com',
#  'www.jeremyferrari.fr',
#  'i1-js-14-3-01-10165-155315903-i.init.cedexis-radar.net',
#  'spaces.slimspots.com',
#  'bmrg.qunar.com',
#  'aluttrin.free.fr',
#  'www.e-junkie.com',
#  '96.docs.google.com',
#  'www.kirghizasia.com',
#  'web.volcanodiscovery.com',
#  'r2games.com',
#  'climate-data.org',
#  'h-deb.clg.qc.ca',
#  'physique.unice.fr',
#  'i1-js-14-3-01-10005-145591129-i.init.cedexis-radar.net',
#  'www.mercer.com',
#  'i1-js-14-3-01-11074-856491568-i.init.cedexis-radar.net',
#  'recommend.union.39.net',
#  'wwv1.onetad.com',
#  'cid-5c67f31e9d0de7a8.users.storage.live.com',
#  'www.sonyericsson.com',
#  'wearesocial-fr.disqus.com',
#  'moussadoum.co',
#  'www.mintek.co.za',
#  'config.office.microsoft.com',
#  'static1.eldiario.es',
#  'ar.cetl.hku.hk',
#  'bcs.baidu.com',
#  'filmspj.viewsurf.com',
#  'i4.social.s-msft.com',
#  'p50.badoo.com',
#  'www-cd1.eurovia.com',
#  'apply.indeed.com',
#  'www.itech.fr',
#  'www.superinsolite.com',
#  'www.dotmyself.net',
#  'i1-js-14-3-01-11074-816963027-i.init.cedexis-radar.net',
#  'mebahiah42.files.wordpress.com',
#  'media.meltybuzz.fr',
#  'blog.neocamino.com',
#  'www.microelec.patricklecoq.fr',
#  'viafoura.s3.amazonaws.com',
#  'i1-js-14-3-01-12160-308877934-i.init.cedexis-radar.net',
#  'www.feedandgrain.com',
#  'w463220.open.ge.tt',
#  'www.pertini.lucca.it',
#  'count.newhua.com',
#  's1223919444.t.eloqua.com',
#  'cdn-api.ooyala.com',
#  'ensemblgenomes.org',
#  'www.mediafont.com',
#  'experts-univers.com',
#  'www.larmand.fr',
#  'imgt2.bdstatic.com',
#  'i1-js-14-3-01-10077-321263788-i.init.cedexis-radar.net',
#  'data.calameo.com',
#  'lastvideo.disqus.com',
#  'www.wondercity.com',
#  'i1-js-14-3-01-11074-963365038-i.init.cedexis-radar.net',
#  'fdb.linternaute.com',
#  'forum.norma4.net.ua',
#  'apps.gagui.org',
#  'edito.kompass.com',
#  'www.zylom.com',
#  'cp91279.biography.com',
#  'www.kelexpert.com',
#  'd2jkam0hji0nkb.cloudfront.net',
#  'static.stuff.co.nz',
#  'www.spiegelblog.net',
#  'i1-js-14-3-01-10005-143964546-i.init.cedexis-radar.net',
#  'v12.cnzz.com',
#  '529-events.olark.com',
#  'www.versailles-grignon.inra.fr',
#  'oferplan.lavanguardia.com',
#  'www.allofficetool.com',
#  'ui.sina.com',
#  'www.bestpsdfreebies.com',
#  'www.psgweb.fr',
#  'cck.isotools.fr',
#  'i1-js-14-3-01-10169-810513572-i.init.cedexis-radar.net',
#  'codekata.pragprog.com',
#  'www.jcdecaux.com',
#  'jesuisnul.wordpress.com',
#  'i1-js-14-3-01-10077-803105680-i.init.cedexis-radar.net',
#  'cachem.disqus.com',
#  'i1-js-14-3-01-11074-580545306-i.init.cedexis-radar.net',
#  'aws-ap-southeast-2a.bench.cedexis.com',
#  'scrat.hellocoton.fr',
#  'collecxia.blob.core.windows.net',
#  'www.seomoz.org',
#  'chart.apis.google.com',
#  'www.norway-travel.com',
#  'www.utilities-online.info',
#  'video.qip.ru',
#  'www.vibertphoto.fr',
#  'www.islamla.com',
#  'www.michelefreud.com',
#  'u.tt',
#  'reviews.ti.com',
#  'webservices.viamichelin.com',
#  'www.campings-franceloc.fr',
#  'teknowlogy.blogspot.com',
#  'canap63.free.fr',
#  'www.sla-aeroport.com',
#  'bapyessir.com',
#  'www.cuisine-et-molecule.fr',
#  'lyc-marie-curie.entauvergne.fr',
#  'i1-js-14-3-01-12670-380343030-i.init.cedexis-radar.net',
#  'www.expansys.fr',
#  'www.enceinte.com',
#  'r4---sn-cg07luel.googlevideo.com',
#  'bookshop.europa.eu',
#  'i1-js-14-3-01-11074-18725555-i.init.cedexis-radar.net',
#  'www.ustream.tv',
#  'img.jogtheweb.com',
#  'www.societechimiquedefrance.fr',
#  'adpublish.ydstatic.com',
#  'asp-indus.secure-zone.net',
#  'i1-js-14-3-01-11074-760177691-i.init.cedexis-radar.net',
#  'labsbewise.disqus.com',
#  'www.atenor-fetes.com',
#  'i1-js-14-3-01-11641-447082705-i.init.cedexis-radar.net',
#  'www.bibmath.net',
#  'www.fgd-com.fr',
#  'i1-js-14-3-01-11074-147930624-i.init.cedexis-radar.net',
#  'img22.mtime.cn',
#  'henri.garreta.perso.luminy.univmed.fr',
#  'api.bankin.com',
#  'i1-js-14-3-01-10013-187024652-i.init.cedexis-radar.net',
#  'hoycinema.abc.es',
#  'cid-3540020918b9ccea.users.storage.live.com',
#  'mods.gdfspfg.com',
#  'winterbash2013.stackexchange.com',
#  'www.brewdog.com',
#  'www.onyxus-web.fr',
#  'www.esrf.eu',
#  'modeles.meteociel.fr',
#  'www.shanghairanking.com',
#  'i1-js-14-3-01-11074-594079428-i.init.cedexis-radar.net',
#  'i1-js-14-3-01-11074-297407461-i.init.cedexis-radar.net',
#  'dobbelsteen.virtuworld.net',
#  'media2.netnpack.net',
#  'letemps.ch',
#  'st0.imhonet.ru',
#  'www.idealangues.com',
#  'www-plani.cea.fr',
#  'cid-0b517a38a82e112f.users.storage.live.com',
#  'fr.msn.com',
#  'jnet.i.lithium.com',
#  'www.developerhelpway.com',
#  'tbe.observatoire-environnement.org',
#  'www.cg57.fr',
#  '7d5phayurc.s.ad6media.fr',
#  'front.sspicy.ru',
#  'math.univ-lille1.fr',
#  'www.oncoprof.net',
#  'static1-bob.rtl.be',
#  'www.guide-sydney.com',
#  'www.7red.se',
#  'cms.ac-martinique.fr',
#  'img3.pconline.com.cn',
#  'resources.gn4me.com',
#  'i1-js-14-3-01-10977-296265887-i.init.cedexis-radar.net',
#  'media.koreus.com',
#  'cv1.litres.ru',
#  'telecharger.phpnuke.org',
#  'p.zol.com.cn',
#  'assets.changyan.sohu.com',
#  'petites-annonces.autoplus.fr',
#  '1.visuels.poliris.com',
#  'cortina.fr',
#  'img546.imageshack.us',
#  'www.optilabs.eu',
#  'acces.pouradultes.com',
#  'africanleadershipcon.wix.com',
#  'coucou.fr',
#  'www.pierron.fr',
#  'zupimages.net',
#  'designyoutrust.com',
#  'web7.jobomas.com',
#  'acces.enfingratuit.com',
#  'editionspaysetterroirs.blogspot.fr',
#  'www.filmxxlgratis.com',
#  'zooxel.com',
#  'www.sandbukt.no',
#  'minotar.net',
#  'www.photo-memory.eu',
#  'ptbus.tgbusdata.cn',
#  'i1-js-14-3-01-11544-548570053-i.init.cedexis-radar.net',
#  'lilypond.org',
#  'www.cbao.fr',
#  '56.img.v4.skyrock.net',
#  'i1-js-14-3-01-10077-416016682-i.init.cedexis-radar.net',
#  'images.linkwithin.com',
#  'theaujasmin.blogspot.fr',
#  'www.images-booknode.com',
#  'www.florame.com',
#  'www.c-nacarat.com',
#  'belsua.dm2303.livefilestore.com',
#  'i1-js-14-3-01-11074-676016927-i.init.cedexis-radar.net',
#  'i1-js-14-3-01-10977-313558920-i.init.cedexis-radar.net',
#  'cid-805172c8c35b9030.users.storage.live.com',
#  'js.pusher.com',
#  'tmblr.co',
#  'www.lapolicenationalerecrute.fr',
#  'i1-js-14-3-01-11074-886755354-i.init.cedexis-radar.net',
#  'abicenter.gestionh.com',
#  'tu.zhibo8.cc',
#  '2259151.r.msn.com',
#  'i1-js-14-3-01-11074-487161296-i.init.cedexis-radar.net',
#  'i1-js-14-3-01-11544-592463580-i.init.cedexis-radar.net',
#  'daf.linternaute.com',
#  'u-eliteathletes.com',
#  'i1-js-14-3-01-12160-630170772-i.init.cedexis-radar.net',
#  'www.opso.fr',
#  'formav-lms-e-learning.fr',
#  'r.duckduckgo.com',
#  'api-eu.kgoma.com',
#  'i1-js-14-3-01-11074-262648084-i.init.cedexis-radar.net',
#  'www.adihadean.ro',
#  'www.u-clermont1.fr',
#  'u-byc5f00w0v.zfr.bkln.wc.s1.b.yahoodns.net',
#  'cdn2.freepik.com',
#  '6h6efur6lm.b.ad6media.fr',
#  'fr.edaboard.com',
#  'www.compteur.fr',
#  'www.zighed.com',
#  'www.font-police.com',
#  '5zxvf450t4.s.ad6media.fr',
#  'static2.pbsrc.com',
#  '586-events.olark.com',
#  'www.ssbwiki.com',
#  'amasty.com',
#  'www.sportune.fr',
#  'img6.imageshack.us',
#  'i1-js-14-3-01-11544-611239156-i.init.cedexis-radar.net',
#  'i1-js-14-3-01-10005-773911492-i.init.cedexis-radar.net',
#  'i1-js-14-3-01-12160-441154815-i.init.cedexis-radar.net',
#  'ec2-us-west-1a.cedexis.com',
#  'ws.yummypets.com',
#  'snt146.mail.live.com',
#  'wtm.dailygeekshow.com',
#  'growingtoprogram.blogspot.fr',
#  'www.biology-online.org',
#  'www.tout-bon.com',
#  'www.terrasol.fr',
#  'gamergen.com',
#  'www.trucsetdeco.com',
#  'i1-js-14-3-01-10281-988120336-i.init.cedexis-radar.net',
#  'skydrive.live.com',
#  'www.solidays.org',
#  'la.epfl.ch',
#  'informatique-python.readthedocs.org',
#  'data.blogs.laprovence.com',
#  'vdsi08abpv.b.ad6media.fr',
#  'www.voyages-photos.fr',
#  'www.newgrafix.de',
#  'www.mrbrowngoesaround.com',
#  'www.arianevennin.fr',
#  'www.youporn.com',
#  'i1-js-14-3-01-10036-354759169-i.init.cedexis-radar.net',
#  'ostez.blogspot.fr',
#  'w1.hoopchina.com.cn',
#  'lig-membres.imag.fr',
#  'www.sowhat-magazine.fr',
#  'www.amelie-claire-illustration.com',
#  'www.strategieclients.com',
#  'static.video.qq.com',
#  'i1-js-14-3-01-10013-399544480-i.init.cedexis-radar.net',
#  'www.beaumont63.fr',
#  'depinfo.u-cergy.fr',
#  'www.photo-dictionary.com',
#  'www.showsplash.com',
#  'www.star-en-maths.tv',
#  'files.support.epson.com',
#  'www.aboneobio.com',
#  'chez-youkette.com',
#  'up1.typepad.com',
#  'www.avenirfoot.com',
#  'i1-js-14-3-01-10077-234229257-i.init.cedexis-radar.net',
#  'i3.answers.microsoft.com',
#  'iufm-web.ujf-grenoble.fr',
#  'i1-js-14-3-01-11074-737933458-i.init.cedexis-radar.net',
#  'i1-js-14-3-01-10036-575302761-i.init.cedexis-radar.net',
#  'i1-js-14-3-01-11074-729062950-i.init.cedexis-radar.net',
#  'mts3.google.com',
#  's.aeriagames.com',
#  'baby.163.com',
#  'i1-js-14-3-01-11074-823261944-i.init.cedexis-radar.net',
#  'stats.popscreen.com',
#  'forum.ubuntu-fr.org',
#  'bemploi.com',
#  'mrbool.com',
#  'www.zelys-designlab.com',
#  'hosted.zeropub.net',
#  'www.xinggan.com',
#  'www.exceltoner.ca',
#  'siliconvalley.blog.lemonde.fr',
#  'widget.cloud.opta.net',
#  'static05.hongkiat.com',
#  'h30097.www3.hp.com',
#  'www.lpcloudsvr203.com',
#  'hcs.ucla.edu',
#  'www.golden-blog-awards.fr',
#  'www.directe.cat',
#  'r1---sn-cg07luer.googlevideo.com',
#  'n2f043s5b8.b.ad6media.fr',
#  'metric.asos.fr',
#  'narutopokelaure.eklablog.com',
#  'sigalondatavis.soup.io',
#  'i1-js-14-3-01-12434-911256027-i.init.cedexis-radar.net',
#  'au-bout-de-la-route.blogspot.com',
#  'www.xiberpix.net',
#  'i1-js-14-3-01-11074-141346762-i.init.cedexis-radar.net',
#  'doug1izaerwt3.cloudfront.net',
#  'i1-js-14-3-01-12160-719906178-i.init.cedexis-radar.net',
#  'seme.uqar.ca',
#  'badmania.fr',
#  'i1-js-14-3-01-10005-908769909-i.init.cedexis-radar.net',
#  'os.qzs.qq.com',
#  'www.nature.com.gate1.inist.fr',
#  'www.cg18.fr',
#  'wwoof.ie',
#  'bernard.lefort.pagesperso-orange.fr',
#  'www.contre-info.com',
#  'i1-js-14-3-01-10608-454608686-i.init.cedexis-radar.net',
#  'www.inquirer.net',
#  'i1-js-14-3-01-10005-875321927-i.init.cedexis-radar.net',
#  'www.espnplayer.com',
#  'www.carriereonline.com',
#  'i1-js-14-3-01-10005-747681425-i.init.cedexis-radar.net',
#  'u-af1u10vr51.wc.yahoodns.net',
#  'front.facetz.net',
#  'penguininside.disqus.com',
#  'i1-js-14-3-01-10077-826285852-i.init.cedexis-radar.net',
#  'livechat.s3.amazonaws.com',
#  'i1-js-14-3-01-11074-750151694-i.init.cedexis-radar.net',
#  'i1-js-14-3-01-10005-216806152-i.init.cedexis-radar.net',
#  'portail.dartybox.com',
#  'cid-cb8dea245868608b.users.storage.live.com',
#  'osm.geobretagne.fr',
#  'www.lafa.fr',
#  'i1-js-14-3-01-10077-160328884-i.init.cedexis-radar.net',
#  'bilan.epub.ch',
#  'fr.cyclopaedia.net',
#  'i1-js-14-3-01-11074-893101857-i.init.cedexis-radar.net',
#  'images.businessweek.com',
#  'brunopicart.pagesperso-orange.fr',
#  'www.xingzuo360.cn',
#  'i1-js-14-3-01-10013-944326204-i.init.cedexis-radar.net',
#  'piwik.madpellzo.fr',
#  'cid-5c45749cdd4611ed.users.storage.live.com',
#  'weather.gtimg.cn',
#  'www.skoda.fr',
#  'www.lave.be',
#  'vacancesachypre.com',
#  'www.w3.org',
#  'www.git-france.org',
#  'cdd.linternaute.com',
#  'smecatronix.com',
#  'i1-js-14-3-01-11074-431452886-i.init.cedexis-radar.net',
#  'www.studilodge.fr',
#  'www.cfenet.cci.fr',
#  'i1-js-14-3-01-11074-581703044-i.init.cedexis-radar.net',
#  'indianprairiecommunity.org',
#  'www.toyota4runners.com',
#  'topsites.fr',
#  'cibois.pagesperso-orange.fr',
#  'nexus.passport.com',
#  'www.protubsa.com',
#  'iut-gmp-toulouse.ups-tlse.fr',
#  'www.lws.fr',
#  'i1-js-14-3-01-11074-584915683-i.init.cedexis-radar.net',
#  'i1-js-14-3-01-10036-551499209-i.init.cedexis-radar.net',
#  'www.talkstats.com',
#  'www.ensta-bretagne.fr',
#  'www.cna.ca',
#  'www.formules-physique.com',
#  'purepeoplefr.disqus.com',
#  'forum.phpfrance.com',
#  'hoopercharles.wordpress.com',
#  'www.voyageursdumonde.fr',
#  'i1-js-14-3-01-10122-529316887-i.init.cedexis-radar.net',
#  'www.denofgeek.com',
#  'lestotosenvadrouille.fr',
#  'i1-js-14-3-01-10013-119543698-i.init.cedexis-radar.net',
#  'pub15.media-clic.com',
#  'www.france-catholique.fr',
#  'piwik.leducdubleuet.info',
#  'supersonique.blogs.challenges.fr',
#  'leedsportal.leeds.ac.uk',
#  'www.infovisual.info',
#  'ud.blog.163.com',
#  'cedexis.cachefly.net',
#  'www.ad6media.fr',
#  'www.lahulotte.fr',
#  'i1-js-14-3-01-11074-893670103-i.init.cedexis-radar.net',
#  'chatsderace.e-monsite.com',
#  'nevrosesurbaines.blogspot.com',
#  'ultraserve.s3-website-us-east-1.amazonaws.com',
#  'www.esfiworld.com',
#  'www4a.wolframalpha.com',
#  'cihr-irsc.sondages-surveys.ca',
#  'www35.glam.com',
#  'on.fb.me',
#  'demotivateur.disqus.com',
#  'www.dell.fr',
#  'www.formafast.fr',
#  'apogee-systems.com',
#  'i1-js-14-3-01-10013-828061668-i.init.cedexis-radar.net',
#  'i1-js-14-3-01-12160-118715677-i.init.cedexis-radar.net',
#  'www.unisasport.edu.au',
#  'www11.track198369.com',
#  'www.laplacemedia.com',
#  'www.next-up.org',
#  'img2.pcpop.com',
#  'www.education.rec.ri.cmu.edu',
#  'svn.codespot.com',
#  'www.apache.org',
#  '13-events.olark.com',
#  'i1-js-14-3-01-11074-112885217-i.init.cedexis-radar.net',
#  'di4gj5lwn0jim.cloudfront.net',
#  'www.csu.edu.au',
#  'www.ilv-edition.com',
#  'www.olivierpons.fr',
#  'www.stickerz.fr',
#  's.joomeo.com',
#  'revision.feuvert.fr',
#  'groups.diigo.com',
#  'www-old.gnome.org',
#  'cdn1.craveonline.com',
#  'www.haskell.org',
#  'www.iceandgreen.net',
#  'i1-js-14-3-01-11074-640323883-i.init.cedexis-radar.net',
#  'i1-js-14-3-01-11074-5424058-i.init.cedexis-radar.net',
#  'i1-js-14-3-01-10077-551522049-i.init.cedexis-radar.net',
#  'st.elohell.net',
#  's-www.lejsl.com',
#  'cid-cdb502f95f08bdd9.users.storage.live.com',
#  'edge.alluremedia.com.au',
#  'docs.pointclouds.org',
#  'pics.plentyoffish.com',
#  'caf.linternaute.com',
#  'i1-js-14-3-01-10340-777786803-i.init.cedexis-radar.net',
#  'www.pau-pyrenees.com',
#  'blog.courtine.org',
#  'malgouyres.org',
#  'www.boutiquepsg.fr',
#  'p1.zdassets.com',
#  'i1-js-14-3-01-11074-783763325-i.init.cedexis-radar.net',
#  'core.kmi.open.ac.uk',
#  'www.lesbridgets.com',
#  'fr.wordpress.com',
#  'business.uwa.edu.au',
#  'flimatech.com',
#  'www.math.ens.fr',
#  'rdldtrk.com',
#  'i1.jeu.info',
#  'i1-js-14-3-01-11074-383556736-i.init.cedexis-radar.net',
#  'topobuv.sk',
#  'dub127.afx.ms',
#  'i1-js-14-3-01-11074-991500230-i.init.cedexis-radar.net',
#  'store.sonyentertainmentnetwork.com',
#  'intmstat.com',
#  'distrib-coffee.ipsl.jussieu.fr',
#  'ns2.bdstatic.com',
#  'www.bienvoyager.com',
#  'weblog.jamisbuck.org',
#  'www.wallpapers21.com',
#  'owncloud.org',
#  'i1-js-14-3-01-10036-316959578-i.init.cedexis-radar.net',
#  'bay169.mail.live.com',
#  'www.arteliagroup.com',
#  'www.ludeales.com',
#  'www.ecosym.univ-montp2.fr',
#  'i1-js-14-3-01-12160-116713862-i.init.cedexis-radar.net',
#  'gadtech.us',
#  'xivdb.com',
#  'www.infinitecrisis.com',
#  'sina.allyes.com',
#  'www.hydroclimato.lu',
#  'aquitaine.media.tourinsoft.eu',
#  'i1-js-14-3-01-11074-139902084-i.init.cedexis-radar.net',
#  'swf.1qwe3r.com',
#  'i1-js-14-3-01-10005-323670288-i.init.cedexis-radar.net',
#  'trp.numergy.bench.cedexis.com',
#  'lolnexus.com',
#  'www.electricite-dolcevita.fr',
#  'stat-z.xywy.com',
#  'i1-js-14-3-01-10005-235203398-i.init.cedexis-radar.net',
#  'vast.bp3846003.btrll.com',
#  'i1-js-14-3-01-11074-385497695-i.init.cedexis-radar.net',
#  'i1-js-14-3-01-11544-10833200-i.init.cedexis-radar.net',
#  'www.kanas.fr',
#  'static2.lamontagne.fr',
#  'redirect.cps.yixun.com',
#  'i1-js-14-3-01-10334-11917972-i.init.cedexis-radar.net',
#  'newslines.ft.com',
#  'redbulltpe.canalblog.com',
#  'www.info-societe.com',
#  'i1-js-14-3-01-11074-785074454-i.init.cedexis-radar.net',
#  'www.hatingmyjob.com',
#  'www.cfmweb.fr',
#  'vodlachainemeteo-vh.akamaihd.net',
#  'www.shirt-tee-shirt.fr',
#  'yoipur1.free.fr',
#  'i1-js-14-3-01-10005-109418317-i.init.cedexis-radar.net',
#  'd3nevzfk7ii3be.cloudfront.net',
#  'abcnatation.fr',
#  'dl6rc8ml1n.b.ad6media.fr',
#  'wikiora.com',
#  'television.telerama.fr',
#  'www.humipapp.com',
#  'pullrequest.disqus.com',
#  'www.premiere.fr',
#  'i1-js-14-3-01-12434-462578753-i.init.cedexis-radar.net',
#  'images.jayisgames.com',
#  'www.donceel.sitew.com',
#  'cmsdesign.au.dk',
#  'i1-js-14-3-01-11074-512741507-i.init.cedexis-radar.net',
#  'www.easymutuelle.fr',
#  'www.planetastronomy.com',
#  's.cmd.pe',
#  'vodp.eurosport.com',
#  'www.net-iris.fr',
#  'rsrc.onthehub.com',
#  'highlyscalable.wordpress.com',
#  'www.tcchx-de-fds.ch',
#  'slot1.images4.wikia.nocookie.net',
#  'i1-js-14-3-01-11074-71218237-i.init.cedexis-radar.net',
#  '98f13.pf.aclst.com',
#  'i1-js-14-3-01-11074-97530129-i.init.cedexis-radar.net',
#  'i1-js-14-3-01-10076-94965332-i.init.cedexis-radar.net',
#  '79.98.96.110',
#  'www.sciences-techniques.univ-nantes.fr',
#  'trends.michaelpage.com',
#  'api.tiles.mapbox.com',
#  'i1-js-14-3-01-10013-55225614-i.init.cedexis-radar.net',
#  'images.mperf.com',
#  'www.animaux.fr',
#  'www.consulfrance-boston.org',
#  'www.sportifconsulting.com',
#  'mobilemail.mail.163.com',
#  'www.automag.be',
#  'www.oldnavy.com',
#  'search.live.com',
#  'thumbs.imagekind.com',
#  'media.one-time-offer.com',
#  'p1.pic.akm.vodst.com',
#  'i1-js-14-3-01-11544-39896029-i.init.cedexis-radar.net',
#  'i1-js-14-3-01-12160-294477184-i.init.cedexis-radar.net',
#  'showroomprive.enquete-en-ligne.com',
#  'd3701cc9l7v9a6.cloudfront.net',
#  'mangerbougerchier.free.fr',
#  'h20158.www2.hp.com',
#  '20.api.urban-rivals.com',
#  '2155206.r.msn.com',
#  'cdn2-new-europe1.ladmedia.fr',
#  '35.docs.google.com',
#  'groupes.codes-sources.com',
#  'www.jurisconsulte.net',
#  'abbreviations.wordcrow.com',
#  'media.somewhere.fr',
#  'www.segen.fr',
#  'recherche.monster.fr',
#  'tr.nl2.sncf-fidelite.com',
#  'recyclaginformatique.free.fr',
#  'speedtest2.rbx.proof.ovh.net',
#  'eaa.linternaute.com',
#  'i1-js-14-3-01-12160-602012957-i.init.cedexis-radar.net',
#  'lefigaro.brightcove.com.edgesuite.net',
#  'www.plonga.com',
#  'www-sop.inria.fr',
#  'webdoc.rfi.fr',
#  'www.bsimard.com',
#  'img710.imageshack.us',
#  'www.catseyemangacafe.be',
#  '744-events.olark.com',
#  'sante-social.emploipublic.fr',
#  'stats.ens-cachan.fr',
#  'secure.ncsoft.com',
#  'grandquebec.com',
#  'media2.avendrealouer.fr',
#  'ru.7red.com',
#  'md1.libe.com',
#  'acidcow.com',
#  'videohttp.tukif.com',
#  'www.commonchinesecharacters.com',
#  'www.masterskidefond.fr',
#  'www.kozayayin.com.tr',
#  'i1-js-14-3-01-10608-112824730-i.init.cedexis-radar.net',
#  'u-add7il8qdv.jor.bkln.wc.s1.b.yahoodns.net',
#  'nssug.baidu.com',
#  'www.basketauvergne.com',
#  'cisco.mwnewsroom.com',
#  'd3e9pgsvkxe0kb.cloudfront.net',
#  'www.veolia.com',
#  'i1-js-14-3-01-10077-768531984-i.init.cedexis-radar.net',
#  'www.freyssinet.fr',
#  'www.wipo.int',
#  'apmep.poitiers.free.fr',
#  '653.studyrama.com',
#  'peruid.pe',
#  'd3svzs8y5qq92x.cloudfront.net',
#  'forum.bouyguestelecom.fr',
#  'optimizermagic.blogspot.com',
#  'i1-js-14-3-01-11544-695132267-i.init.cedexis-radar.net',
#  'www.electrofitness.com',
#  'web.worldbank.org',
#  'andreas-hess.info',
#  '9f5zsmndxb.s.ad6media.fr',
#  'i1-js-14-3-01-11074-657065464-i.init.cedexis-radar.net',
#  'www.devshed.com',
#  'i1-js-14-3-01-12434-192397970-i.init.cedexis-radar.net',
#  'www.rbkmoney.ru',
#  'usebobik.com',
#  'paolitech.univ-corse.fr',
#  'www.burgess-shale.rom.on.ca',
#  'imagecache6.allposters.com',
#  'axisin.free.fr',
#  'saas.gravityrd.com',
#  'i4.modatoi.com',
#  'profs.cmaisonneuve.qc.ca',
#  'djibril.developpez.com',
#  'd1lhrpl5i6czkn.cloudfront.net',
#  'i1-js-14-3-01-11074-34171344-i.init.cedexis-radar.net',
#  'ginoux.univ-tln.fr',
#  'career.hm.com',
#  'www.africaguinee.com',
#  'www.scbt.com',
#  'www.espace-technologie.com',
#  'i1-js-14-3-01-11074-614197948-i.init.cedexis-radar.net',
#  'd2hpw6pw4uian4.cloudfront.net',
#  'cdn6.business2community.com',
#  'i1-js-14-3-01-11074-293759387-i.init.cedexis-radar.net',
#  'i1-js-14-3-01-11074-818087465-i.init.cedexis-radar.net',
#  'www.bienpublic.com',
#  'fr.vid.web.480p.acsta.net',
#  'bks7.books.google.fr',
#  'i1-js-14-3-01-10005-293354826-i.init.cedexis-radar.net',
#  'infos-live.blogspot.fr',
#  'apo.cssmi.qc.ca',
#  'ww.googl.fr',
#  'd3fqh47ho4rujh.cloudfront.net',
#  'www.citations-francaises.fr',
#  'www.lesobservateurs.ch',
#  'i1-js-14-3-01-10710-470360312-i.init.cedexis-radar.net',
#  'ksmcp.com',
#  'fr.ria.ru',
#  'www.coestrenos.com',
#  'i1-js-14-3-01-11074-287785157-i.init.cedexis-radar.net',
#  'fournisseurs-electricite.com',
#  'sabine.chauvet1.free.fr',
#  'ovnis-direct.com',
#  'i1-js-14-3-01-11074-165884745-i.init.cedexis-radar.net',
#  'img1.gtsstatic.com',
#  'install2.optimum-installer.com',
#  'mymemory.translated.net',
#  'www.produits-laitiers.com',
#  'www.creatif-public.net',
#  'i1-js-14-3-01-10169-690017331-i.init.cedexis-radar.net',
#  'lecompagnon.info',
#  'i1-js-14-3-01-12160-74011562-i.init.cedexis-radar.net',
#  'cid-d66a0c7521a22814.users.storage.live.com',
#  'media2.lesmenuires.com',
#  'www.directmatin.fr',
#  'runners.fr',
#  's.cnzz.net',
#  'brightcove01-secure.brightcove.com',
#  'www.naturabuy.fr',
#  'keep.google.com',
#  'im2.ovipets.com',
#  'i1-js-14-3-01-11641-711975076-i.init.cedexis-radar.net',
#  'fansshare.disqus.com',
#  'r6---sn-cg07lues.googlevideo.com',
#  'progmedia.edgesuite.net',
#  'cmarket.kejet.net',
#  'www.coursera.org',
#  'm.lingq.com',
#  'i1-js-14-3-01-11641-839262726-i.init.cedexis-radar.net',
#  'zarkanzar.blogspot.fr',
#  'www.thumbs-share.com',
#  'l.levrel.free.fr',
#  'www.filmstreamingvk.ws',
#  'mickaelpechaud.free.fr',
#  'home.mis.u-picardie.fr',
#  'dtm.underarmour.com',
#  'www.cafepress.fr',
#  'www.projectenvision.com',
#  'img512.imageshack.us',
#  'virginjs.serv2me.com',
#  'i1-js-14-3-01-11074-921074826-i.init.cedexis-radar.net',
#  'www.pob-technology.com',
#  'www.altair.com',
#  'pixel2451.everesttech.net',
#  'www.etlaqualite.com',
#  'i1-js-14-3-01-10077-631175281-i.init.cedexis-radar.net',
#  'www.highfun.com',
#  'www.paroledemamans.com',
#  'cid-5495d8163157ec55.users.storage.live.com',
#  'scr3.templatemonster.com',
#  'www.unit-conversion.info',
#  'www.silverdisc.com',
#  'dlbeta.com',
#  'i1-js-14-3-01-12317-175963925-i.init.cedexis-radar.net',
#  'www.youtubeinmp4.com',
#  'marketplace.eclipse.org',
#  'compteur.typhlophile.com',
#  'www.ufolep51.org',
#  'www.fifa.com',
#  'islamstory.canalblog.com',
#  'ug.oreilly.com',
#  'www.laposte.fr',
#  'surtout-ne-lisez-pas-ce-blog.blogspot.fr',
#  'mes-contacts.services.sfr.fr',
#  'www.lanouvellerepublique.fr',
#  'cplusn.disqus.com',
#  'media.krapahute.com',
#  'www.transports-fontanon.fr',
#  'malsup.github.com',
#  'i.askdev.ru',
#  'you.leparisien.fr',
#  'www.lasaucissedemarseille.com',
#  'www.location-etudiant.fr',
#  'i1-js-14-3-01-12160-981418343-i.init.cedexis-radar.net',
#  'i1-js-14-3-01-11074-880318728-i.init.cedexis-radar.net',
#  'image.tmdb.org',
#  'touch-static-france.oxylane.com',
#  'encyclopedie.arbre-celtique.com',
#  'd1ez3020z2uu9b.cloudfront.net',
#  '27.api.urban-rivals.com',
#  ...]
